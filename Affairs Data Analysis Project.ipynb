# %%
import pandas as pd
import plotly.io as pio
pio.renderers.default = 'notebook'
import plotly.express as px
import plotly.graph_objects as go
afs = pd.read_csv('Affairs.csv')
afs
# Out:
#      Unnamed: 0  affairs  gender   age  yearsmarried children  religiousness  \
# 0             4        0    male  37.0         10.00       no              3
# 1             5        0  female  27.0          4.00       no              4
# 2            11        0  female  32.0         15.00      yes              1
# 3            16        0    male  57.0         15.00      yes              5
# 4            23        0    male  22.0          0.75       no              2
# ..          ...      ...     ...   ...           ...      ...            ...
# 596        1938        1    male  22.0          1.50      yes              1
# 597        1941        7  female  32.0         10.00      yes              2
# 598        1954        2    male  32.0         10.00      yes              2
# 599        1959        2    male  22.0          7.00      yes              3
# 600        9010        1  female  32.0         15.00      yes              3
#
#      education  occupation  rating
# ...

# %%
# male and female percentage of affairs
afs['have affair'] = afs['affairs'] != 0
MvF = afs[['gender','have affair']].groupby('gender').sum()
numMF =  afs[['gender','have affair']].groupby('gender').count()
perMF = (MvF/numMF)*100
MvF_result = pd.merge(pd.merge(MvF, numMF, on='gender'), perMF.round(1), on = 'gender')
MvF_result.columns = ['# have affair', 'total population', '% have affair']
MvF_result
# Out:
#         # have affair  total population  % have affair
# gender
# female             72               315           22.9
# male               78               286           27.3

# %%
FemData = afs.loc[afs['gender']=='female']
ManData = afs.loc[afs['gender']=='male']

# %%
def affPerc(*args) :
    if args[0] == 'F' :
        data = FemData
        data1 = f'F{args[1][:3]}1'
        data1 = f'F{args[1][:3]}2'
        data3 = f'F{args[1][:3]}3'
        result = f'F{args[1][:3]}_result'
        print(result)
    else :
        data = ManData
        data1 = f'M{args[1][:3]}1'
        data1 = f'M{args[1][:3]}2'
        data3 = f'M{args[1][:3]}3'
        result = f'M{args[1][:3]}_result'
        print(result)
    data1 = data[[args[1],'have affair']].groupby(args[1]).sum() #total pop
    data2 = data[[args[1],'have affair']].groupby(args[1]).count() ## have affair
    data3 = (data1/data2)*100 # % have affair
    result = pd.merge(pd.merge(data1, data2, on=args[1]), data3.round(1), on = args[1])
    result.columns = ['# have affair', f'total {args[0]} pop', '% have affair']
    return result

# %%
def figPerc(*args):
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=args[0].index, y=args[0]["% have affair"],name='male'))
    fig.add_trace(go.Scatter(x=args[1].index, y=args[1]["% have affair"],name='female'))
    fig.update_layout(
        title=f"{args[2]} vs Affairs",
        xaxis_title=f"{args[2]}",
        yaxis_title="% of Affair",
        legend_title="Gender")
    return fig.show()

# %%
# Female : occupation and affairs
Focc_result=affPerc('F','occupation')
Focc_result
# Out:
# Focc_result
#             # have affair  total F pop  % have affair
# occupation
# 1                      22          112           19.6
# 2                       0            3            0.0
# 3                      10           27           37.0
# 4                       9           29           31.0
# 5                      26          115           22.6
# 6                       4           27           14.8
# 7                       1            2           50.0

# %%
# Male: occupation and affairs
Mocc_result=affPerc('M','occupation')
Mocc_result
# Out:
# Mocc_result
#             # have affair  total M pop  % have affair
# occupation
# 1                       1            1          100.0
# 2                       3           10           30.0
# 3                       5           20           25.0
# 4                      12           39           30.8
# 5                      18           89           20.2
# 6                      35          116           30.2
# 7                       4           11           36.4

# %%
figPerc(Mocc_result,Focc_result,'Occupation')
# Out:
# <div>                            <div id="1dec1065-f63a-4baa-9a3d-7f977155f347" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dec1065-f63a-4baa-9a3d-7f977155f347")) {                    Plotly.newPlot(                        "1dec1065-f63a-4baa-9a3d-7f977155f347",                        [{"name":"male","x":[1,2,3,4,5,6,7],"y":[100.0,30.0,25.0,30.8,20.2,30.2,36.4],"type":"scatter"},{"name":"female","x":[1,2,3,4,5,6,7],"y":[19.6,0.0,37.0,31.0,22.6,14.8,50.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444
# ...

# %%
# Female: education and affair
Fedu_result=affPerc('F','education')
Fedu_result
# Out:
# Fedu_result
#            # have affair  total F pop  % have affair
# education
# 9                      2            4           50.0
# 12                     9           36           25.0
# 14                    23          106           21.7
# 16                    10           70           14.3
# 17                    16           52           30.8
# 18                    11           45           24.4
# 20                     1            2           50.0

# %%
# Male: education and affair
Medu_result=affPerc('M','education')
Medu_result
# Out:
# Medu_result
#            # have affair  total M pop  % have affair
# education
# 9                      0            3            0.0
# 12                     4            8           50.0
# 14                    12           48           25.0
# 16                    10           45           22.2
# 17                    11           37           29.7
# 18                    22           67           32.8
# 20                    19           78           24.4

# %%
figPerc(Medu_result,Fedu_result,'Education')
# Out:
# <div>                            <div id="f2500107-95c5-48aa-9481-5866f4b96c5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2500107-95c5-48aa-9481-5866f4b96c5f")) {                    Plotly.newPlot(                        "f2500107-95c5-48aa-9481-5866f4b96c5f",                        [{"name":"male","x":[9,12,14,16,17,18,20],"y":[0.0,50.0,25.0,22.2,29.7,32.8,24.4],"type":"scatter"},{"name":"female","x":[9,12,14,16,17,18,20],"y":[50.0,25.0,21.7,14.3,30.8,24.4,50.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44
# ...

# %%
# Female: age and affair
Fage_result=affPerc('F','age')
Fage_result
# Out:
# Fage_result
#       # have affair  total F pop  % have affair
# age
# 17.5              3            5           60.0
# 22.0              8           80           10.0
# 27.0             19           83           22.9
# 32.0             20           62           32.3
# 37.0              4           32           12.5
# 42.0             12           28           42.9
# 47.0              2           11           18.2
# 52.0              3            9           33.3
# 57.0              1            5           20.0

# %%
# Male: age and affair
Mage_result=affPerc('M','age')
Mage_result
# Out:
# Mage_result
#       # have affair  total M pop  % have affair
# age
# 17.5              0            1            0.0
# 22.0              8           37           21.6
# 27.0             17           70           24.3
# 32.0             18           53           34.0
# 37.0             19           56           33.9
# 42.0              6           28           21.4
# 47.0              5           12           41.7
# 52.0              3           12           25.0
# 57.0              2           17           11.8

# %%
figPerc(Mage_result,Fage_result,'Age')
# Out:
# <div>                            <div id="8ccc7e64-03a5-439d-ba46-3991c604772e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ccc7e64-03a5-439d-ba46-3991c604772e")) {                    Plotly.newPlot(                        "8ccc7e64-03a5-439d-ba46-3991c604772e",                        [{"name":"male","x":[17.5,22.0,27.0,32.0,37.0,42.0,47.0,52.0,57.0],"y":[0.0,21.6,24.3,34.0,33.9,21.4,41.7,25.0,11.8],"type":"scatter"},{"name":"female","x":[17.5,22.0,27.0,32.0,37.0,42.0,47.0,52.0,57.0],"y":[60.0,10.0,22.9,32.3,12.5,42.9,18.2,33.3,20.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f
# ...

# %%
# Female: marital status and affair
Fyea_result=affPerc('F','yearsmarried')
Fyea_result
# Out:
# Fyea_result
#               # have affair  total F pop  % have affair
# yearsmarried
# 0.125                     0            5            0.0
# 0.417                     0            6            0.0
# 0.750                     3           21           14.3
# 1.500                     5           53            9.4
# 4.000                    11           41           26.8
# 7.000                    12           49           24.5
# 10.000                    9           36           25.0
# 15.000                   32          104           30.8

# %%
Frat_result=affPerc('F','rating')
Frat_result
# Out:
# Frat_result
#         # have affair  total F pop  % have affair
# rating
# 1                   5           11           45.5
# 2                  16           35           45.7
# 3                  16           46           34.8
# 4                  17           93           18.3
# 5                  18          130           13.8

# %%
Fchi_result=affPerc('F','children')
Fchi_result
# Out:
# Fchi_result
#           # have affair  total F pop  % have affair
# children
# no                   12           99           12.1
# yes                  60          216           27.8

# %%
# Male: marital status and affair
Myea_result=affPerc('M','yearsmarried')
Myea_result
# Out:
# Myea_result
#               # have affair  total M pop  % have affair
# yearsmarried
# 0.125                     1            6           16.7
# 0.417                     1            4           25.0
# 0.750                     0           10            0.0
# 1.500                     7           35           20.0
# 4.000                    16           64           25.0
# 7.000                    11           33           33.3
# 10.000                   12           34           35.3
# 15.000                   30          100           30.0

# %%
Mrat_result=affPerc('M','rating')
Mrat_result
# Out:
# Mrat_result
#         # have affair  total M pop  % have affair
# rating
# 1                   3            5           60.0
# 2                  17           31           54.8
# 3                  11           47           23.4
# 4                  31          101           30.7
# 5                  16          102           15.7

# %%
Mchi_result=affPerc('M','children')
Mchi_result
# Out:
# Mchi_result
#           # have affair  total M pop  % have affair
# children
# no                   15           72           20.8
# yes                  63          214           29.4

# %%
figPerc(Myea_result,Fyea_result,'Years Married')
# Out:
# <div>                            <div id="95bc1fcb-c95c-47ba-ad0d-6e87647b030a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95bc1fcb-c95c-47ba-ad0d-6e87647b030a")) {                    Plotly.newPlot(                        "95bc1fcb-c95c-47ba-ad0d-6e87647b030a",                        [{"name":"male","x":[0.125,0.417,0.75,1.5,4.0,7.0,10.0,15.0],"y":[16.7,25.0,0.0,20.0,25.0,33.3,35.3,30.0],"type":"scatter"},{"name":"female","x":[0.125,0.417,0.75,1.5,4.0,7.0,10.0,15.0],"y":[0.0,0.0,14.3,9.4,26.8,24.5,25.0,30.8],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#
# ...

# %%
figPerc(Mrat_result,Frat_result,'Marriage Rating')
# Out:
# <div>                            <div id="01fb5f4e-7bb5-4a91-ba32-9776024d5944" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01fb5f4e-7bb5-4a91-ba32-9776024d5944")) {                    Plotly.newPlot(                        "01fb5f4e-7bb5-4a91-ba32-9776024d5944",                        [{"name":"male","x":[1,2,3,4,5],"y":[60.0,54.8,23.4,30.7,15.7],"type":"scatter"},{"name":"female","x":[1,2,3,4,5],"y":[45.5,45.7,34.8,18.3,13.8],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555
# ...

# %%
figPerc(Mchi_result,Fchi_result,'Have Children')
# Out:
# <div>                            <div id="57e19b8d-02bd-4287-9235-1c6a47edc5b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57e19b8d-02bd-4287-9235-1c6a47edc5b2")) {                    Plotly.newPlot(                        "57e19b8d-02bd-4287-9235-1c6a47edc5b2",                        [{"name":"male","x":["no","yes"],"y":[20.8,29.4],"type":"scatter"},{"name":"female","x":["no","yes"],"y":[12.1,27.8],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666
# ...

# %%
# Female: religion and affair
Frel_result = affPerc('F','religiousness')
Frel_result
# Out:
# Frel_result
#                # have affair  total F pop  % have affair
# religiousness
# 1                         10           20           50.0
# 2                         17           91           18.7
# 3                         21           75           28.0
# 4                         17           93           18.3
# 5                          7           36           19.4

# %%
# Male: religion and affair
Mrel_result = affPerc('M','religiousness')
Mrel_result
# Out:
# Mrel_result
#                # have affair  total M pop  % have affair
# religiousness
# 1                         10           28           35.7
# 2                         24           73           32.9
# 3                         22           54           40.7
# 4                         16           97           16.5
# 5                          6           34           17.6

# %%
(Mrel_result,Frel_result,'Religiousness')
# Out:
# <div>                            <div id="dd491ddc-a772-45f4-9110-5a603153635b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd491ddc-a772-45f4-9110-5a603153635b")) {                    Plotly.newPlot(                        "dd491ddc-a772-45f4-9110-5a603153635b",                        [{"name":"male","x":[1,2,3,4,5],"y":[35.7,32.9,40.7,16.5,17.6],"type":"scatter"},{"name":"female","x":[1,2,3,4,5],"y":[50.0,18.7,28.0,18.3,19.4],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555
# ...
